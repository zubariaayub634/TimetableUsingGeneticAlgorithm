# %% [markdown]
# ### Assumptions
# 1. Every professor will have a unique name
# 2. A student will belong to only one section and take classes with that section only

# %% [markdown]
# # Constants

# %%
import enum
class Days(enum.Enum):
    MONDAY=0
    TUESDAY=1
    WEDNESDAY=2
    THURSDAY=3
    FRIDAY=4

# %%
class StartTimeSlots(enum.Enum):
    t9_00=1
    t10_00=2
    t11_00=3
    t12_00=4
    t13_00=5
    t14_00=6
    t15_00=7
    t16_00=8

# %%
class Classrooms(enum.Enum):
    A301=0
    A302=1
    A303=2
    A305=3
    A310=4
    A311=5

# %%
POPULATION_SIZE=10

# %%
hard_constraints=[
    "No teacher can hold two classes at the same time",
"No section can listen for two classes at the same time",
"No classroom can receive two classes at the same time",
"No teacher can hold three consecutive classes",
"There will be no class before 8:30 am and after 5:00 pm",
"University will remain close as there will be no class on weekends (Sat, Sun)"
]

# %%
soft_constraints=[
    "There will be no class from 1-2 on Friday.",
    "No section can hold three consecutive classes",
    "A subject having multiple forms, such as lectures and labs, the preferred order is: lecture and lab",
    "One hour for faculty meeting in a week when there is no class except Friday’s prayer break."
]

# %% [markdown]
# # Classes

# %%
import random
class Gene:
    def __init__(self):
        self.day=random.choice(list(Days))
        self.startTimeSlot=random.choice(list(StartTimeSlots))
        self.classroom=random.choice(list(Classrooms))
        #self.day=Days.MONDAY
        #self.startTimeSlot=StartTimeSlots.t9_00
        #self.classroom=Classrooms.A301
        print("("+str(self.day)+","+str(self.startTimeSlot)+","+str(self.classroom)+"), ")

# %%
class Chromosome:
    def __init__(self,slots):
        self.slots=slots
        for i in range(len(data)):
            self.genes.append(Gene())
        print(self.genes)
    
    def __str__(self):
        string=""
        for gene in self.genes:
            string+=("("+str(gene.day)+","+str(gene.startTimeSlot)+","+str(gene.classroom)+"), ")
        return string

# %%
class Slot:
    def __init__(self,name,course,section):
        self.name=name
        self.course=course
        self.section=section
        self.duration=1 #in hours
        self.gene=None
        
    def __str__(self):
        return "name: "+self.name+", course: "+self.course+", section: "+self.section+", duration: "+self.duration

# %% [markdown]
# # Course-Instructor Allocation

# %%
instructors=["Ammad","Ibrar","Mishaal","Mesha"]
course=["AI","DS","CA","ITC"]
sections=["A","B","C","D"]
data=[]
for i in range(POPULATION_SIZE):
    listt=[]
    for k in range(0,len(instructors)):
        for j in range(0,len(sections)):
            p1=Slot(instructors[k],course=course[k],section=sections[j])
            print(instructors[k],course[k],sections[j])
            listt.append(p1)
    print()
    data.append(listt)
# Out:
# Ammad AI A
# Ammad AI B
# Ammad AI C
# Ammad AI D
# Ibrar DS A
# Ibrar DS B
# Ibrar DS C
# Ibrar DS D
# Mishaal CA A
# Mishaal CA B
# Mishaal CA C
# Mishaal CA D
# Mesha ITC A
# Mesha ITC B
# Mesha ITC C
# Mesha ITC D
#
# Ammad AI A
# Ammad AI B
# Ammad AI C
# Ammad AI D
# Ibrar DS A
# Ibrar DS B
# Ibrar DS C
# Ibrar DS D
# Mishaal CA A
# Mishaal CA B
# Mishaal CA C
# Mishaal CA D
# Mesha ITC A
# Mesha ITC B
# Mesha ITC C
# Mesha ITC D
#
# Ammad AI A
# Ammad AI B
# Ammad AI C
# Ammad AI D
# Ibrar DS A
# Ibrar DS B
# Ibrar DS C
# Ibrar DS D
# Mishaal CA A
# Mishaal CA B
# Mishaal CA C
# Mishaal CA D
# Mesha ITC A
# Mesha ITC B
# Mesha ITC C
# Mesha ITC D
#
# Ammad AI A
# Ammad AI B
# Ammad AI C
# Ammad AI D
# Ibrar DS A
# Ibrar DS B
# Ibrar DS C
# Ibrar DS D
# Mishaal CA A
# Mishaal CA B
# Mishaal CA C
# Mishaal CA D
# Mesha ITC A
# Mesha ITC B
# Mesha ITC C
# Mesha ITC D
#
# Ammad AI A
# Ammad AI B
# Ammad AI C
# Ammad AI D
# Ibrar DS A
# Ibrar DS B
# Ibrar DS C
# Ibrar DS D
# Mishaal CA A
# Mishaal CA B
# Mishaal CA C
# Mishaal CA D
# Mesha ITC A
# Mesha ITC B
# Mesha ITC C
# Mesha ITC D
#
# Ammad AI A
# Ammad AI B
# Ammad AI C
# Ammad AI D
# Ibrar DS A
# Ibrar DS B
# Ibrar DS C
# Ibrar DS D
# Mishaal CA A
# Mishaal CA B
# Mishaal CA C
# Mishaal CA D
# Mesha ITC A
# Mesha ITC B
# Mesha ITC C
# Mesha ITC D
#
# Ammad AI A
# Ammad AI B
# Ammad AI C
# Ammad AI D
# Ibrar DS A
# Ibrar DS B
# Ibrar DS C
# Ibrar DS D
# Mishaal CA A
# Mishaal CA B
# Mishaal CA C
# Mishaal CA D
# Mesha ITC A
# Mesha ITC B
# Mesha ITC C
# Mesha ITC D
#
# Ammad AI A
# Ammad AI B
# Ammad AI C
# Ammad AI D
# Ibrar DS A
# Ibrar DS B
# Ibrar DS C
# Ibrar DS D
# Mishaal CA A
# Mishaal CA B
# Mishaal CA C
# Mishaal CA D
# Mesha ITC A
# Mesha ITC B
# Mesha ITC C
# Mesha ITC D
#
# Ammad AI A
# Ammad AI B
# Ammad AI C
# Ammad AI D
# Ibrar DS A
# Ibrar DS B
# Ibrar DS C
# Ibrar DS D
# Mishaal CA A
# Mishaal CA B
# Mishaal CA C
# Mishaal CA D
# Mesha ITC A
# Mesha ITC B
# Mesha ITC C
# Mesha ITC D
#
# Ammad AI A
# Ammad AI B
# Ammad AI C
# Ammad AI D
# Ibrar DS A
# Ibrar DS B
# Ibrar DS C
# Ibrar DS D
# Mishaal CA A
# Mishaal CA B
# Mishaal CA C
# Mishaal CA D
# Mesha ITC A
# Mesha ITC B
# Mesha ITC C
# Mesha ITC D

# %%
data
# Out:
# [[<__main__.Slot at 0x7f68446aaca0>,
#   <__main__.Slot at 0x7f68446aadf0>,
#   <__main__.Slot at 0x7f68446aaf10>,
#   <__main__.Slot at 0x7f68446aac10>,
#   <__main__.Slot at 0x7f68446aad30>,
#   <__main__.Slot at 0x7f68446aadc0>,
#   <__main__.Slot at 0x7f68446aaee0>,
#   <__main__.Slot at 0x7f68446aaf70>,
#   <__main__.Slot at 0x7f68446aafa0>,
#   <__main__.Slot at 0x7f68446b3370>],
#  [<__main__.Slot at 0x7f68446b31c0>,
#   <__main__.Slot at 0x7f68446b3730>,
#   <__main__.Slot at 0x7f68446b3bb0>,
#   <__main__.Slot at 0x7f68446b3f70>,
#   <__main__.Slot at 0x7f68446b33d0>,
#   <__main__.Slot at 0x7f68446b95e0>,
#   <__main__.Slot at 0x7f68446b9940>,
#   <__main__.Slot at 0x7f68446b9f40>,
#   <__main__.Slot at 0x7f68446b3eb0>,
#   <__main__.Slot at 0x7f68446b3970>,
#   <__main__.Slot at 0x7f68446b3040>,
#   <__main__.Slot at 0x7f68446b9df0>,
#   <__main__.Slot at 0x7f68446b3e50>,
#   <__main__.Slot at 0x7f68446b9640>,
#   <__main__.Slot at 0x7f68446b32b0>,
#   <__main__.Slot at 0x7f68446b3a00>],
#  [<__main__.Slot at 0x7f68446b3a30>,
#   <__main__.Slot at 0x7f68446b98b0>,
#   <__main__.Slot at 0x7f68446b9f70>,
#   <__main__.Slot at 0x7f68446b3c70>,
#   <__main__.Slot at 0x7f68446b3670>,
#   <__main__.Slot at 0x7f68446b9370>,
#   <__main__.Slot at 0x7f68446b3640>,
#   <__main__.Slot at 0x7f68446b3cd0>,
#   <__main__.Slot at 0x7f68446b37c0>,
#   <__main__.Slot at 0x7f68446b96d0>,
#   <__main__.Slot at 0x7f68446b9100>,
#   <__main__.Slot at 0x7f68446b9460>,
#   <__main__.Slot at 0x7f68446b9c10>,
#   <__main__.Slot at 0x7f68446b95b0>,
#   <__main__.Slot at 0x7f68446b9bb0>,
#   <__main__.Slot at 0x7f68446b3d90>]]

# %% [markdown]
# # Time Table Generation using GA

# %%
def generateRandomGenes(): #generates random genes for each class slot
    for timetable in data: 
        for _class in timetable:
            _class.gene=Gene()
        print()

# %%
import numpy as np
def checkConstraintSatisfaction(chromosome): #checks if the constraints are being satisfied by a chromosome
    #check datatypye of chromosome is list of Slot
    
    fitness_score=0
    
    #check hard constraint at index 0: No teacher can hold two classes at the same time
    teacherSlotDict={}
    for instructor in instructors:
        allSlots=[slot for slot in chromosome if slot.name == instructor]
        print(len(allSlots))
        for slot in range(len(allSlots)):
            print(allSlots[slot].name,allSlots[slot].course, allSlots[slot].section, allSlots[slot].gene.day, allSlots[slot].gene.startTimeSlot)
            for slot2 in range(slot+1,len(allSlots)):
                if allSlots[slot].gene.day==allSlots[slot2].gene.day and allSlots[slot].gene.startTimeSlot==allSlots[slot2].gene.startTimeSlot:
                    print("-------------------------------------- duplicate --------------------------------------")
                    
    return fitness_score

# %%
generateRandomGenes()
checkConstraintSatisfaction(data[0])
# Out:
# (Days.WEDNESDAY,StartTimeSlots.t11_00,Classrooms.A302),
# (Days.THURSDAY,StartTimeSlots.t10_00,Classrooms.A311),
# (Days.TUESDAY,StartTimeSlots.t16_00,Classrooms.A301),
# (Days.THURSDAY,StartTimeSlots.t11_00,Classrooms.A310),
# (Days.WEDNESDAY,StartTimeSlots.t12_00,Classrooms.A302),
# (Days.THURSDAY,StartTimeSlots.t15_00,Classrooms.A311),
# (Days.THURSDAY,StartTimeSlots.t14_00,Classrooms.A310),
# (Days.FRIDAY,StartTimeSlots.t9_00,Classrooms.A305),
# (Days.FRIDAY,StartTimeSlots.t11_00,Classrooms.A310),
# (Days.MONDAY,StartTimeSlots.t12_00,Classrooms.A305),
# (Days.MONDAY,StartTimeSlots.t14_00,Classrooms.A305),
# (Days.WEDNESDAY,StartTimeSlots.t13_00,Classrooms.A311),
# (Days.WEDNESDAY,StartTimeSlots.t11_00,Classrooms.A311),
# (Days.MONDAY,StartTimeSlots.t12_00,Classrooms.A305),
# (Days.FRIDAY,StartTimeSlots.t14_00,Classrooms.A305),
# (Days.TUESDAY,StartTimeSlots.t10_00,Classrooms.A303),
#
# (Days.FRIDAY,StartTimeSlots.t10_00,Classrooms.A301),
# (Days.MONDAY,StartTimeSlots.t11_00,Classrooms.A303),
# (Days.THURSDAY,StartTimeSlots.t13_00,Classrooms.A301),
# (Days.THURSDAY,StartTimeSlots.t16_00,Classrooms.A311),
# (Days.TUESDAY,StartTimeSlots.t13_00,Classrooms.A303),
# (Days.WEDNESDAY,StartTimeSlots.t15_00,Classrooms.A311),
# (Days.WEDNESDAY,StartTimeSlots.t12_00,Classrooms.A302),
# (Days.FRIDAY,StartTimeSlots.t9_00,Classrooms.A310),
# (Days.THURSDAY,StartTimeSlots.t14_00,Classrooms.A302),
# (Days.WEDNESDAY,StartTimeSlots.t16_00,Classrooms.A301),
# (Days.MONDAY,StartTimeSlots.t9_00,Classrooms.A303),
# (Days.MONDAY,StartTimeSlots.t16_00,Classrooms.A303),
# (Days.THURSDAY,StartTimeSlots.t10_00,Classrooms.A303),
# (Days.THURSDAY,StartTimeSlots.t15_00,Classrooms.A301),
# (Days.FRIDAY,StartTimeSlots.t9_00,Classrooms.A302),
# (Days.THURSDAY,StartTimeSlots.t9_00,Classrooms.A310),
#
# (Days.THURSDAY,StartTimeSlots.t11_00,Classrooms.A305),
# (Days.TUESDAY,StartTimeSlots.t13_00,Classrooms.A301),
# (Days.FRIDAY,StartTimeSlots.t16_00,Classrooms.A311),
# (Days.MONDAY,StartTimeSlots.t16_00,Classrooms.A303),
# (Days.MONDAY,StartTimeSlots.t14_00,Classrooms.A303),
# (Days.THURSDAY,StartTimeSlots.t15_00,Classrooms.A302),
# (Days.THURSDAY,StartTimeSlots.t16_00,Classrooms.A303),
# (Days.WEDNESDAY,StartTimeSlots.t12_00,Classrooms.A310),
# (Days.THURSDAY,StartTimeSlots.t12_00,Classrooms.A301),
# (Days.MONDAY,StartTimeSlots.t9_00,Classrooms.A303),
# (Days.TUESDAY,StartTimeSlots.t15_00,Classrooms.A311),
# (Days.WEDNESDAY,StartTimeSlots.t12_00,Classrooms.A302),
# (Days.THURSDAY,StartTimeSlots.t16_00,Classrooms.A301),
# (Days.FRIDAY,StartTimeSlots.t9_00,Classrooms.A301),
# (Days.MONDAY,StartTimeSlots.t16_00,Classrooms.A301),
# (Days.TUESDAY,StartTimeSlots.t13_00,Classrooms.A302),
#
# (Days.THURSDAY,StartTimeSlots.t11_00,Classrooms.A310),
# (Days.FRIDAY,StartTimeSlots.t10_00,Classrooms.A311),
# (Days.FRIDAY,StartTimeSlots.t13_00,Classrooms.A311),
# (Days.TUESDAY,StartTimeSlots.t11_00,Classrooms.A301),
# (Days.TUESDAY,StartTimeSlots.t15_00,Classrooms.A311),
# (Days.WEDNESDAY,StartTimeSlots.t13_00,Classrooms.A305),
# (Days.TUESDAY,StartTimeSlots.t16_00,Classrooms.A305),
# (Days.THURSDAY,StartTimeSlots.t9_00,Classrooms.A311),
# (Days.TUESDAY,StartTimeSlots.t12_00,Classrooms.A302),
# (Days.WEDNESDAY,StartTimeSlots.t12_00,Classrooms.A301),
# (Days.MONDAY,StartTimeSlots.t12_00,Classrooms.A311),
# (Days.MONDAY,StartTimeSlots.t9_00,Classrooms.A305),
# (Days.FRIDAY,StartTimeSlots.t10_00,Classrooms.A305),
# (Days.WEDNESDAY,StartTimeSlots.t13_00,Classrooms.A311),
# (Days.MONDAY,StartTimeSlots.t11_00,Classrooms.A302),
# (Days.FRIDAY,StartTimeSlots.t15_00,Classrooms.A303),
#
# (Days.TUESDAY,StartTimeSlots.t14_00,Classrooms.A310),
# (Days.FRIDAY,StartTimeSlots.t10_00,Classrooms.A302),
# (Days.MONDAY,StartTimeSlots.t10_00,Classrooms.A303),
# (Days.FRIDAY,StartTimeSlots.t13_00,Classrooms.A303),
# (Days.TUESDAY,StartTimeSlots.t12_00,Classrooms.A303),
# (Days.WEDNESDAY,StartTimeSlots.t14_00,Classrooms.A311),
# (Days.THURSDAY,StartTimeSlots.t9_00,Classrooms.A311),
# (Days.MONDAY,StartTimeSlots.t9_00,Classrooms.A301),
# (Days.TUESDAY,StartTimeSlots.t16_00,Classrooms.A303),
# (Days.FRIDAY,StartTimeSlots.t13_00,Classrooms.A311),
# (Days.MONDAY,StartTimeSlots.t15_00,Classrooms.A311),
# (Days.MONDAY,StartTimeSlots.t11_00,Classrooms.A311),
# (Days.MONDAY,StartTimeSlots.t10_00,Classrooms.A301),
# (Days.THURSDAY,StartTimeSlots.t16_00,Classrooms.A301),
# (Days.WEDNESDAY,StartTimeSlots.t11_00,Classrooms.A310),
# (Days.FRIDAY,StartTimeSlots.t10_00,Classrooms.A310),
#
# (Days.FRIDAY,StartTimeSlots.t11_00,Classrooms.A303),
# (Days.FRIDAY,StartTimeSlots.t9_00,Classrooms.A303),
# (Days.TUESDAY,StartTimeSlots.t12_00,Classrooms.A302),
# (Days.THURSDAY,StartTimeSlots.t15_00,Classrooms.A302),
# (Days.WEDNESDAY,StartTimeSlots.t12_00,Classrooms.A301),
# (Days.MONDAY,StartTimeSlots.t11_00,Classrooms.A301),
# (Days.MONDAY,StartTimeSlots.t15_00,Classrooms.A310),
# (Days.FRIDAY,StartTimeSlots.t10_00,Classrooms.A310),
# (Days.WEDNESDAY,StartTimeSlots.t11_00,Classrooms.A301),
# (Days.WEDNESDAY,StartTimeSlots.t14_00,Classrooms.A301),
# (Days.TUESDAY,StartTimeSlots.t9_00,Classrooms.A301),
# (Days.TUESDAY,StartTimeSlots.t14_00,Classrooms.A311),
# (Days.FRIDAY,StartTimeSlots.t10_00,Classrooms.A303),
# (Days.TUESDAY,StartTimeSlots.t11_00,Classrooms.A305),
# (Days.THURSDAY,StartTimeSlots.t14_00,Classrooms.A301),
# (Days.MONDAY,StartTimeSlots.t15_00,Classrooms.A310),
#
# (Days.WEDNESDAY,StartTimeSlots.t11_00,Classrooms.A305),
# (Days.THURSDAY,StartTimeSlots.t13_00,Classrooms.A301),
# (Days.WEDNESDAY,StartTimeSlots.t10_00,Classrooms.A305),
# (Days.THURSDAY,StartTimeSlots.t12_00,Classrooms.A301),
# (Days.FRIDAY,StartTimeSlots.t13_00,Classrooms.A302),
# (Days.WEDNESDAY,StartTimeSlots.t11_00,Classrooms.A303),
# (Days.WEDNESDAY,StartTimeSlots.t10_00,Classrooms.A305),
# (Days.TUESDAY,StartTimeSlots.t14_00,Classrooms.A311),
# (Days.FRIDAY,StartTimeSlots.t10_00,Classrooms.A311),
# (Days.THURSDAY,StartTimeSlots.t9_00,Classrooms.A301),
# (Days.WEDNESDAY,StartTimeSlots.t10_00,Classrooms.A311),
# (Days.FRIDAY,StartTimeSlots.t13_00,Classrooms.A303),
# (Days.TUESDAY,StartTimeSlots.t9_00,Classrooms.A305),
# (Days.THURSDAY,StartTimeSlots.t16_00,Classrooms.A303),
# (Days.FRIDAY,StartTimeSlots.t11_00,Classrooms.A310),
# (Days.MONDAY,StartTimeSlots.t10_00,Classrooms.A301),
#
# (Days.TUESDAY,StartTimeSlots.t9_00,Classrooms.A310),
# (Days.WEDNESDAY,StartTimeSlots.t13_00,Classrooms.A311),
# (Days.WEDNESDAY,StartTimeSlots.t9_00,Classrooms.A303),
# (Days.FRIDAY,StartTimeSlots.t12_00,Classrooms.A302),
# (Days.FRIDAY,StartTimeSlots.t16_00,Classrooms.A302),
# (Days.MONDAY,StartTimeSlots.t9_00,Classrooms.A301),
# (Days.FRIDAY,StartTimeSlots.t16_00,Classrooms.A302),
# (Days.FRIDAY,StartTimeSlots.t12_00,Classrooms.A311),
# (Days.THURSDAY,StartTimeSlots.t16_00,Classrooms.A311),
# (Days.WEDNESDAY,StartTimeSlots.t9_00,Classrooms.A302),
# (Days.FRIDAY,StartTimeSlots.t10_00,Classrooms.A303),
# (Days.THURSDAY,StartTimeSlots.t10_00,Classrooms.A303),
# (Days.WEDNESDAY,StartTimeSlots.t13_00,Classrooms.A305),
# (Days.WEDNESDAY,StartTimeSlots.t11_00,Classrooms.A303),
# (Days.THURSDAY,StartTimeSlots.t11_00,Classrooms.A305),
# (Days.WEDNESDAY,StartTimeSlots.t14_00,Classrooms.A303),
#
# (Days.MONDAY,StartTimeSlots.t15_00,Classrooms.A305),
# (Days.THURSDAY,StartTimeSlots.t9_00,Classrooms.A305),
# (Days.FRIDAY,StartTimeSlots.t11_00,Classrooms.A311),
# (Days.WEDNESDAY,StartTimeSlots.t11_00,Classrooms.A311),
# (Days.FRIDAY,StartTimeSlots.t10_00,Classrooms.A303),
# (Days.THURSDAY,StartTimeSlots.t14_00,Classrooms.A303),
# (Days.THURSDAY,StartTimeSlots.t11_00,Classrooms.A310),
# (Days.TUESDAY,StartTimeSlots.t15_00,Classrooms.A305),
# (Days.MONDAY,StartTimeSlots.t12_00,Classrooms.A311),
# (Days.TUESDAY,StartTimeSlots.t11_00,Classrooms.A301),
# (Days.THURSDAY,StartTimeSlots.t15_00,Classrooms.A301),
# (Days.THURSDAY,StartTimeSlots.t12_00,Classrooms.A301),
# (Days.TUESDAY,StartTimeSlots.t12_00,Classrooms.A303),
# (Days.FRIDAY,StartTimeSlots.t14_00,Classrooms.A302),
# (Days.FRIDAY,StartTimeSlots.t12_00,Classrooms.A302),
# (Days.TUESDAY,StartTimeSlots.t9_00,Classrooms.A310),
#
# (Days.TUESDAY,StartTimeSlots.t12_00,Classrooms.A301),
# (Days.THURSDAY,StartTimeSlots.t16_00,Classrooms.A303),
# (Days.FRIDAY,StartTimeSlots.t10_00,Classrooms.A301),
# (Days.TUESDAY,StartTimeSlots.t14_00,Classrooms.A311),
# (Days.MONDAY,StartTimeSlots.t11_00,Classrooms.A303),
# (Days.MONDAY,StartTimeSlots.t14_00,Classrooms.A301),
# (Days.TUESDAY,StartTimeSlots.t11_00,Classrooms.A303),
# (Days.TUESDAY,StartTimeSlots.t12_00,Classrooms.A310),
# (Days.WEDNESDAY,StartTimeSlots.t13_00,Classrooms.A302),
# (Days.MONDAY,StartTimeSlots.t16_00,Classrooms.A303),
# (Days.THURSDAY,StartTimeSlots.t11_00,Classrooms.A301),
# (Days.FRIDAY,StartTimeSlots.t13_00,Classrooms.A305),
# (Days.WEDNESDAY,StartTimeSlots.t12_00,Classrooms.A303),
# (Days.MONDAY,StartTimeSlots.t11_00,Classrooms.A311),
# (Days.THURSDAY,StartTimeSlots.t9_00,Classrooms.A303),
# (Days.MONDAY,StartTimeSlots.t16_00,Classrooms.A310),
#
# 4
# Ammad AI A Days.WEDNESDAY StartTimeSlots.t11_00
# Ammad AI B Days.THURSDAY StartTimeSlots.t10_00
# Ammad AI C Days.TUESDAY StartTimeSlots.t16_00
# Ammad AI D Days.THURSDAY StartTimeSlots.t11_00
# 4
# Ibrar DS A Days.WEDNESDAY StartTimeSlots.t12_00
# Ibrar DS B Days.THURSDAY StartTimeSlots.t15_00
# Ibrar DS C Days.THURSDAY StartTimeSlots.t14_00
# Ibrar DS D Days.FRIDAY StartTimeSlots.t9_00
# 4
# Mishaal CA A Days.FRIDAY StartTimeSlots.t11_00
# Mishaal CA B Days.MONDAY StartTimeSlots.t12_00
# Mishaal CA C Days.MONDAY StartTimeSlots.t14_00
# Mishaal CA D Days.WEDNESDAY StartTimeSlots.t13_00
# 4
# Mesha ITC A Days.WEDNESDAY StartTimeSlots.t11_00
# Mesha ITC B Days.MONDAY StartTimeSlots.t12_00
# Mesha ITC C Days.FRIDAY StartTimeSlots.t14_00
# Mesha ITC D Days.TUESDAY StartTimeSlots.t10_00
