# %% [markdown]
# ### Assumptions
# 1. Every professor will have a unique name
# 2. A student will belong to only one section and take classes with that section only

# %% [markdown]
# # Constants

# %%
import enum
class Days(enum.Enum):
    MONDAY=0
    TUESDAY=1
    WEDNESDAY=2
    THURSDAY=3
    FRIDAY=4

# %%
class StartTimeSlots(enum.Enum):
    t9_00=1
    t10_00=2
    t11_00=3
    t12_00=4
    t13_00=5
    t14_00=6
    t15_00=7
    t16_00=8

# %%
class Classrooms(enum.Enum):
    A301=0
    A302=1
    A303=2
    A305=3
    A310=4
    A311=5

# %%
POPULATION_SIZE=10

# %%
hard_constraints=[
    "No teacher can hold two classes at the same time",
"No section can listen for two classes at the same time",
"No classroom can receive two classes at the same time",
"No teacher can hold three consecutive classes",
"There will be no class before 8:30 am and after 5:00 pm",
"University will remain close as there will be no class on weekends (Sat, Sun)"
]

# %%
soft_constraints=[
    "There will be no class from 1-2 on Friday.",
    "No section can hold three consecutive classes",
    "A subject having multiple forms, such as lectures and labs, the preferred order is: lecture and lab",
    "One hour for faculty meeting in a week when there is no class except Friday’s prayer break."
]

# %% [markdown]
# # Classes

# %%
import random
class Gene:
    def __init__(self):
        #self.day=random.choice(list(Days))
        #self.startTimeSlot=random.choice(list(StartTimeSlots))
        #self.classroom=random.choice(list(Classrooms))
        self.day=Days.MONDAY
        self.startTimeSlot=StartTimeSlots.t9_00
        self.classroom=Classrooms.A301
        print("("+str(self.day)+","+str(self.startTimeSlot)+","+str(self.classroom)+"), ")

# %%
class Chromosome:
    def __init__(self,data):
        self.genes=[]
        for i in range(len(data)):
            self.genes.append(Gene())
        print(self.genes)
    
    def __str__(self):
        string=""
        for gene in self.genes:
            string+=("("+str(gene.day)+","+str(gene.startTimeSlot)+","+str(gene.classroom)+"), ")
        return string

# %%
class Slot:
    def __init__(self,name,course,section):
        self.name=name
        self.course=course
        self.section=section
        self.duration=1 #in hours
        self.gene=None
        
    def __str__(self):
        return "name: "+self.name+", course: "+self.course+", section: "+self.section+", duration: "+self.duration

# %% [markdown]
# # Course-Instructor Allocation

# %%
instructors=["Ammad","Ibrar","Mishaal","Mesha"]
course=["AI","DS","CA","ITC"]
sections=["A","B","C","D"]
data=[]
for i in range(POPULATION_SIZE):
    listt=[]
    for k in range(0,len(instructors)):
        for j in range(0,len(sections)):
            p1=Slot(instructors[k],course=course[k],section=sections[j])
            print(instructors[k],course[k],sections[j])
            listt.append(p1)
    print()
    data.append(listt)
# Out:
# Ammad AI A
# Ammad AI B
# Ammad AI C
# Ammad AI D
# Ibrar DS A
# Ibrar DS B
# Ibrar DS C
# Ibrar DS D
# Mishaal CA A
# Mishaal CA B
# Mishaal CA C
# Mishaal CA D
# Mesha ITC A
# Mesha ITC B
# Mesha ITC C
# Mesha ITC D
#
# Ammad AI A
# Ammad AI B
# Ammad AI C
# Ammad AI D
# Ibrar DS A
# Ibrar DS B
# Ibrar DS C
# Ibrar DS D
# Mishaal CA A
# Mishaal CA B
# Mishaal CA C
# Mishaal CA D
# Mesha ITC A
# Mesha ITC B
# Mesha ITC C
# Mesha ITC D
#
# Ammad AI A
# Ammad AI B
# Ammad AI C
# Ammad AI D
# Ibrar DS A
# Ibrar DS B
# Ibrar DS C
# Ibrar DS D
# Mishaal CA A
# Mishaal CA B
# Mishaal CA C
# Mishaal CA D
# Mesha ITC A
# Mesha ITC B
# Mesha ITC C
# Mesha ITC D
#
# Ammad AI A
# Ammad AI B
# Ammad AI C
# Ammad AI D
# Ibrar DS A
# Ibrar DS B
# Ibrar DS C
# Ibrar DS D
# Mishaal CA A
# Mishaal CA B
# Mishaal CA C
# Mishaal CA D
# Mesha ITC A
# Mesha ITC B
# Mesha ITC C
# Mesha ITC D
#
# Ammad AI A
# Ammad AI B
# Ammad AI C
# Ammad AI D
# Ibrar DS A
# Ibrar DS B
# Ibrar DS C
# Ibrar DS D
# Mishaal CA A
# Mishaal CA B
# Mishaal CA C
# Mishaal CA D
# Mesha ITC A
# Mesha ITC B
# Mesha ITC C
# Mesha ITC D
#
# Ammad AI A
# Ammad AI B
# Ammad AI C
# Ammad AI D
# Ibrar DS A
# Ibrar DS B
# Ibrar DS C
# Ibrar DS D
# Mishaal CA A
# Mishaal CA B
# Mishaal CA C
# Mishaal CA D
# Mesha ITC A
# Mesha ITC B
# Mesha ITC C
# Mesha ITC D
#
# Ammad AI A
# Ammad AI B
# Ammad AI C
# Ammad AI D
# Ibrar DS A
# Ibrar DS B
# Ibrar DS C
# Ibrar DS D
# Mishaal CA A
# Mishaal CA B
# Mishaal CA C
# Mishaal CA D
# Mesha ITC A
# Mesha ITC B
# Mesha ITC C
# Mesha ITC D
#
# Ammad AI A
# Ammad AI B
# Ammad AI C
# Ammad AI D
# Ibrar DS A
# Ibrar DS B
# Ibrar DS C
# Ibrar DS D
# Mishaal CA A
# Mishaal CA B
# Mishaal CA C
# Mishaal CA D
# Mesha ITC A
# Mesha ITC B
# Mesha ITC C
# Mesha ITC D
#
# Ammad AI A
# Ammad AI B
# Ammad AI C
# Ammad AI D
# Ibrar DS A
# Ibrar DS B
# Ibrar DS C
# Ibrar DS D
# Mishaal CA A
# Mishaal CA B
# Mishaal CA C
# Mishaal CA D
# Mesha ITC A
# Mesha ITC B
# Mesha ITC C
# Mesha ITC D
#
# Ammad AI A
# Ammad AI B
# Ammad AI C
# Ammad AI D
# Ibrar DS A
# Ibrar DS B
# Ibrar DS C
# Ibrar DS D
# Mishaal CA A
# Mishaal CA B
# Mishaal CA C
# Mishaal CA D
# Mesha ITC A
# Mesha ITC B
# Mesha ITC C
# Mesha ITC D

# %%
data
# Out:
# [[<__main__.Slot at 0x7f5dd850a610>,
#   <__main__.Slot at 0x7f5dd850a880>,
#   <__main__.Slot at 0x7f5dd852b280>,
#   <__main__.Slot at 0x7f5dd855cdc0>,
#   <__main__.Slot at 0x7f5dd850a760>,
#   <__main__.Slot at 0x7f5dd852ba00>,
#   <__main__.Slot at 0x7f5dd852bca0>,
#   <__main__.Slot at 0x7f5dd852bf40>,
#   <__main__.Slot at 0x7f5dd851e250>,
#   <__main__.Slot at 0x7f5dd8526550>,
#   <__main__.Slot at 0x7f5dd85268b0>,
#   <__main__.Slot at 0x7f5dd8526af0>,
#   <__main__.Slot at 0x7f5dd85262b0>,
#   <__main__.Slot at 0x7f5dd8526eb0>,
#   <__main__.Slot at 0x7f5dd8526e80>,
#   <__main__.Slot at 0x7f5dd8526cd0>,
#   <__main__.Slot at 0x7f5dd8526d90>,
#   <__main__.Slot at 0x7f5dd855ca60>,
#   <__main__.Slot at 0x7f5dd8526a30>,
#   <__main__.Slot at 0x7f5dd8526640>],
#  [<__main__.Slot at 0x7f5dd85264c0>,
#   <__main__.Slot at 0x7f5dd8526190>,
#   <__main__.Slot at 0x7f5dd851edf0>,
#   <__main__.Slot at 0x7f5dd8526370>,
#   <__main__.Slot at 0x7f5dd8526460>,
#   <__main__.Slot at 0x7f5dd8526070>,
#   <__main__.Slot at 0x7f5dd8526f40>,
#   <__main__.Slot at 0x7f5dd85269d0>,
#   <__main__.Slot at 0x7f5dd8526520>,
#   <__main__.Slot at 0x7f5dd8526160>,
#   <__main__.Slot at 0x7f5dd8526ac0>,
#   <__main__.Slot at 0x7f5dd851ed00>,
#   <__main__.Slot at 0x7f5dd8526bb0>,
#   <__main__.Slot at 0x7f5dd851e9a0>,
#   <__main__.Slot at 0x7f5dd851e2b0>,
#   <__main__.Slot at 0x7f5dd851e610>]]

# %% [markdown]
# # Time Table Generation using GA

# %%
def generateRandomGenes(): #generates random genes for each class slot
    for timetable in data: 
        for _class in timetable:
            _class.gene=Gene()
        print()

# %%
import numpy as np
def checkConstraintSatisfaction(chromosome): #checks if the constraints are being satisfied by a chromosome
    #check datatypye of chromosome is list of Slot
    
    #check hard constraint no 1: No teacher can hold two classes at the same time
    teacherSlotDict={}
    for instructor in instructors:
        allSlots=[slot for slot in chromosome if slot.name == instructor]
        print(len(allSlots))
        for slot in range(len(allSlots)):
            print(allSlots[slot].name,allSlots[slot].course, allSlots[slot].section, allSlots[slot].gene.day, allSlots[slot].gene.startTimeSlot)
            for slot2 in range(slot+1,len(allSlots)):
                if allSlots[slot].gene.day==allSlots[slot2].gene.day and allSlots[slot].gene.startTimeSlot==allSlots[slot2].gene.startTimeSlot:
                    print("-------------------------------------- duplicate --------------------------------------")

# %%
generateRandomGenes()
checkConstraintSatisfaction(data[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-450d2ab14e1c> in <module>
# ----> 1 generateRandomGenes()
#       2 checkConstraintSatisfaction(data[0])
#
# <ipython-input-12-9723d8333969> in generateRandomGenes()
#       2     for timetable in data:
#       3         for _class in timetable:
# ----> 4             _class.gene=Gene()
#       5         print()
#
# <ipython-input-7-22ecf1da5d4e> in __init__(self)
#       5         #self.startTimeSlot=random.choice(list(StartTimeSlots))
#       6         #self.classroom=random.choice(list(Classrooms))
# ----> 7         self.day=Days.Monday
#       8         self.startTimeSlot=StartTimeSlots.t9_00
#       9         self.classroom=Classrooms.A301
#
# /usr/lib/python3.8/enum.py in __getattr__(cls, name)
#     344             return cls._member_map_[name]
#     345         except KeyError:
# --> 346             raise AttributeError(name) from None
#     347
#     348     def __getitem__(cls, name):
#
# AttributeError: Monday
